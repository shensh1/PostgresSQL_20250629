# %%
import source

def main():
    results = source.get_stations_names()
    if results:
        for station in results:
            print(station)
    else:
        print("無法取得車站資料")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 12
#       9         print("無法取得車站資料")
#      11 if __name__ == "__main__":
# ---> 12     main()
#
# Cell In[23], line 4, in main()
#       3 def main():
# ----> 4     results = source.get_stations_names()
#       5     if results:
#       6         for station in results:
#
# AttributeError: module 'source' has no attribute 'get_stations_names'
