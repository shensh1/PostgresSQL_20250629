# %%
#請建立一個範本list
my_list = [1, 2, 3, 4, 5]
print(type(my_list))
my_list.append(6)
print(my_list)
# Out:
# <class 'list'>
# [1, 2, 3, 4, 5, 6]

# %%
#請建立一個範本list
my_list = [1, 2, 3, 4, 5]
#並且建立常用的實體方法
my_list.append(6)
print(my_list)
my_list.remove(2)
print(my_list)
my_list.insert(1, 10)
print(my_list)
my_list.sort()
print(my_list)
my_list.reverse()
print(my_list)
my_list.clear()
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 3, 4, 5, 6]
# [1, 10, 3, 4, 5, 6]
# [1, 3, 4, 5, 6, 10]
# [10, 6, 5, 4, 3, 1]
# []

# %%
#我有一個list,要使用for迴圈,請將list中的每個元素乘以2
my_list = [1, 2, 3, 4, 5]
for i in my_list:
    print(i * 2)

for word in "Apple":
    print(word)
# Out:
# 2
# 4
# 6
# 8
# 10
# A
# p
# p
# l
# e
